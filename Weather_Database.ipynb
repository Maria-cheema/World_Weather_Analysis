# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 727

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]  
        city_description = city_weather["weather"][0]["description"]     
        # Append the city information into the city_data list
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | san vicente
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | tutoia
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | mar del plata
# Processing Record 8 of Set 1 | ballina
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | fairbanks
# Processing Record 12 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | mushie
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 1 | pankrushikha
# Processing Record 20 of Set 1 | lagoa
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | pangody
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | khani
# Processing Record 29 of Set 1 | grindavik
# Processing Record 30 of Set 1 | te anau
# Processing Record 31 of Set 1 | homer
# Processing Record 32 of Set 1 | ancud
# Processing Record 33 of Set 1 | tevaitoa
# Processing Record 34 of Set 1 | bubaque
# Processing Record 35 of Set 1 | mokhsogollokh
# Processing Record 36 of Set 1 | provideniya
# Processing Record 37 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 1 | broome
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 1 | comodoro rivadavia
# Processing Record 43 of Set 1 | kavieng
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | methoni
# Processing Record 47 of Set 1 | narsaq
# Processing Record 48 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 1 | guajara-mirim
# City not found. Skipping...
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | maykain
# City not found. Skipping...
# Processing Record 2 of Set 2 | arraial do cabo
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | okha
# Processing Record 7 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | saint-georges
# Processing Record 11 of Set 2 | aquidauana
# Processing Record 12 of Set 2 | ponta do sol
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | esperance
# Processing Record 15 of Set 2 | grand gaube
# Processing Record 16 of Set 2 | macae
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | ugoofaaru
# Processing Record 19 of Set 2 | asau
# Processing Record 20 of Set 2 | ziro
# Processing Record 21 of Set 2 | jarvakandi
# Processing Record 22 of Set 2 | manono
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | vallam
# Processing Record 25 of Set 2 | port elizabeth
# Processing Record 26 of Set 2 | kahului
# Processing Record 27 of Set 2 | coahuayana
# Processing Record 28 of Set 2 | muscat
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | sitka
# Processing Record 31 of Set 2 | lodja
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | buala
# Processing Record 35 of Set 2 | aklavik
# Processing Record 36 of Set 2 | dikson
# Processing Record 37 of Set 2 | severo-kurilsk
# Processing Record 38 of Set 2 | loukhi
# Processing Record 39 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 2 | san andres
# Processing Record 41 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 2 | bogatyye saby
# Processing Record 43 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 2 | houma
# Processing Record 45 of Set 2 | pisco
# Processing Record 46 of Set 2 | kaspiyskiy
# Processing Record 47 of Set 2 | chuy
# Processing Record 48 of Set 2 | jumla
# Processing Record 49 of Set 2 | bambous virieux
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | west bay
# Processing Record 3 of Set 3 | cabo san lucas
# Processing Record 4 of Set 3 | vila velha
# Processing Record 5 of Set 3 | urucui
# Processing Record 6 of Set 3 | fortuna
# Processing Record 7 of Set 3 | bac lieu
# Processing Record 8 of Set 3 | guerrero negro
# Processing Record 9 of Set 3 | wanning
# Processing Record 10 of Set 3 | geraldton
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | henties bay
# Processing Record 13 of Set 3 | tuktoyaktuk
# Processing Record 14 of Set 3 | sainte-suzanne
# Processing Record 15 of Set 3 | faanui
# Processing Record 16 of Set 3 | talnakh
# Processing Record 17 of Set 3 | mehamn
# Processing Record 18 of Set 3 | jamsa
# Processing Record 19 of Set 3 | aksarka
# Processing Record 20 of Set 3 | camrose
# Processing Record 21 of Set 3 | skjervoy
# Processing Record 22 of Set 3 | burnie
# Processing Record 23 of Set 3 | akyab
# Processing Record 24 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 3 | cap malheureux
# Processing Record 26 of Set 3 | rio grande
# Processing Record 27 of Set 3 | cariati
# Processing Record 28 of Set 3 | bathsheba
# Processing Record 29 of Set 3 | mikkeli
# Processing Record 30 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | axim
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 3 | tabou
# Processing Record 35 of Set 3 | saint-philippe
# Processing Record 36 of Set 3 | camocim
# Processing Record 37 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 3 | rio gallegos
# Processing Record 39 of Set 3 | vostok
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 3 | seoul
# Processing Record 42 of Set 3 | wajir
# Processing Record 43 of Set 3 | beringovskiy
# Processing Record 44 of Set 3 | luanda
# Processing Record 45 of Set 3 | kutum
# Processing Record 46 of Set 3 | tiarei
# Processing Record 47 of Set 3 | cherskiy
# Processing Record 48 of Set 3 | kaohsiung
# Processing Record 49 of Set 3 | revelstoke
# Processing Record 50 of Set 3 | marsa matruh
# Processing Record 1 of Set 4 | amahai
# Processing Record 2 of Set 4 | ulladulla
# Processing Record 3 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 4 of Set 4 | naze
# Processing Record 5 of Set 4 | auki
# Processing Record 6 of Set 4 | adrar
# Processing Record 7 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 4 | staszow
# Processing Record 9 of Set 4 | pevek
# Processing Record 10 of Set 4 | maksatikha
# Processing Record 11 of Set 4 | te karaka
# Processing Record 12 of Set 4 | kuytun
# Processing Record 13 of Set 4 | wasilla
# Processing Record 14 of Set 4 | eyl
# Processing Record 15 of Set 4 | maniitsoq
# Processing Record 16 of Set 4 | akdepe
# Processing Record 17 of Set 4 | cidreira
# Processing Record 18 of Set 4 | san carlos de bariloche
# Processing Record 19 of Set 4 | koch bihar
# Processing Record 20 of Set 4 | griffith
# Processing Record 21 of Set 4 | ballinrobe
# Processing Record 22 of Set 4 | huanren
# Processing Record 23 of Set 4 | bilibino
# Processing Record 24 of Set 4 | victoria
# Processing Record 25 of Set 4 | chokurdakh
# Processing Record 26 of Set 4 | pedro betancourt
# Processing Record 27 of Set 4 | tasiilaq
# Processing Record 28 of Set 4 | avera
# Processing Record 29 of Set 4 | sal rei
# Processing Record 30 of Set 4 | bairiki
# Processing Record 31 of Set 4 | constitucion
# Processing Record 32 of Set 4 | gagnoa
# Processing Record 33 of Set 4 | havre-saint-pierre
# Processing Record 34 of Set 4 | green river
# Processing Record 35 of Set 4 | lodingen
# Processing Record 36 of Set 4 | sisimiut
# Processing Record 37 of Set 4 | gijon
# Processing Record 38 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 4 | hamilton
# Processing Record 40 of Set 4 | ribeira grande
# Processing Record 41 of Set 4 | souillac
# Processing Record 42 of Set 4 | nome
# Processing Record 43 of Set 4 | brandfort
# Processing Record 44 of Set 4 | san cristobal
# Processing Record 45 of Set 4 | den helder
# Processing Record 46 of Set 4 | arlit
# Processing Record 47 of Set 4 | biak
# Processing Record 48 of Set 4 | sabang
# Processing Record 49 of Set 4 | iqaluit
# Processing Record 50 of Set 4 | ixtapa
# Processing Record 1 of Set 5 | longyearbyen
# Processing Record 2 of Set 5 | mahebourg
# Processing Record 3 of Set 5 | kenai
# Processing Record 4 of Set 5 | acarau
# Processing Record 5 of Set 5 | port blair
# Processing Record 6 of Set 5 | hvide sande
# Processing Record 7 of Set 5 | seminole
# Processing Record 8 of Set 5 | kachug
# Processing Record 9 of Set 5 | meadow lake
# Processing Record 10 of Set 5 | klaksvik
# Processing Record 11 of Set 5 | trelaze
# Processing Record 12 of Set 5 | kargalinskaya
# Processing Record 13 of Set 5 | pirassununga
# Processing Record 14 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 5 | ilulissat
# Processing Record 16 of Set 5 | port hardy
# Processing Record 17 of Set 5 | san jose el idolo
# Processing Record 18 of Set 5 | galich
# Processing Record 19 of Set 5 | quang ngai
# Processing Record 20 of Set 5 | hofn
# Processing Record 21 of Set 5 | luderitz
# Processing Record 22 of Set 5 | dingle
# Processing Record 23 of Set 5 | yellowknife
# Processing Record 24 of Set 5 | cockburn town
# Processing Record 25 of Set 5 | pershotravneve
# Processing Record 26 of Set 5 | nisia floresta
# Processing Record 27 of Set 5 | lata
# Processing Record 28 of Set 5 | sao filipe
# Processing Record 29 of Set 5 | seekonk
# Processing Record 30 of Set 5 | krasnoselkup
# Processing Record 31 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 5 | lorengau
# Processing Record 33 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 5 | shelburne
# Processing Record 35 of Set 5 | guanica
# Processing Record 36 of Set 5 | tiksi
# Processing Record 37 of Set 5 | lompoc
# Processing Record 38 of Set 5 | beloha
# Processing Record 39 of Set 5 | tilichiki
# Processing Record 40 of Set 5 | rorvik
# Processing Record 41 of Set 5 | hasaki
# Processing Record 42 of Set 5 | alofi
# Processing Record 43 of Set 5 | balabac
# Processing Record 44 of Set 5 | yara
# Processing Record 45 of Set 5 | gizo
# Processing Record 46 of Set 5 | kaeo
# Processing Record 47 of Set 5 | sorong
# Processing Record 48 of Set 5 | airai
# Processing Record 49 of Set 5 | praia
# Processing Record 50 of Set 5 | beira
# Processing Record 1 of Set 6 | kupang
# Processing Record 2 of Set 6 | chiredzi
# Processing Record 3 of Set 6 | marsh harbour
# Processing Record 4 of Set 6 | feldkirchen an der donau
# Processing Record 5 of Set 6 | bandarbeyla
# Processing Record 6 of Set 6 | belize
# Processing Record 7 of Set 6 | gat
# Processing Record 8 of Set 6 | micheweni
# Processing Record 9 of Set 6 | kudahuvadhoo
# Processing Record 10 of Set 6 | allapalli
# Processing Record 11 of Set 6 | bad liebenwerda
# Processing Record 12 of Set 6 | hurghada
# Processing Record 13 of Set 6 | mount gambier
# Processing Record 14 of Set 6 | chaltyr
# Processing Record 15 of Set 6 | port hedland
# Processing Record 16 of Set 6 | torbay
# Processing Record 17 of Set 6 | fengrun
# Processing Record 18 of Set 6 | touros
# Processing Record 19 of Set 6 | sept-iles
# Processing Record 20 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 21 of Set 6 | tiznit
# Processing Record 22 of Set 6 | katsuura
# Processing Record 23 of Set 6 | eskisehir
# Processing Record 24 of Set 6 | zyryanka
# Processing Record 25 of Set 6 | camacha
# Processing Record 26 of Set 6 | velventos
# Processing Record 27 of Set 6 | atar
# Processing Record 28 of Set 6 | verkhnevilyuysk
# Processing Record 29 of Set 6 | adolfo lopez mateos
# Processing Record 30 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 6 | tacuarembo
# Processing Record 32 of Set 6 | hualmay
# Processing Record 33 of Set 6 | aswan
# Processing Record 34 of Set 6 | slave lake
# Processing Record 35 of Set 6 | saryozek
# Processing Record 36 of Set 6 | rundu
# Processing Record 37 of Set 6 | port-gentil
# Processing Record 38 of Set 6 | comalcalco
# Processing Record 39 of Set 6 | norman wells
# Processing Record 40 of Set 6 | phan thiet
# Processing Record 41 of Set 6 | kaitangata
# Processing Record 42 of Set 6 | leningradskiy
# Processing Record 43 of Set 6 | cabra
# Processing Record 44 of Set 6 | mount isa
# Processing Record 45 of Set 6 | taoudenni
# Processing Record 46 of Set 6 | pontes e lacerda
# Processing Record 47 of Set 6 | payson
# Processing Record 48 of Set 6 | aloleng
# Processing Record 49 of Set 6 | oga
# Processing Record 50 of Set 6 | mingaora
# Processing Record 1 of Set 7 | oranjemund
# Processing Record 2 of Set 7 | hailar
# Processing Record 3 of Set 7 | thinadhoo
# Processing Record 4 of Set 7 | lafia
# Processing Record 5 of Set 7 | tezu
# Processing Record 6 of Set 7 | tarakan
# Processing Record 7 of Set 7 | bengkulu
# Processing Record 8 of Set 7 | pimentel
# Processing Record 9 of Set 7 | clyde river
# Processing Record 10 of Set 7 | osmanabad
# Processing Record 11 of Set 7 | mahon
# Processing Record 12 of Set 7 | teeli
# Processing Record 13 of Set 7 | fort nelson
# Processing Record 14 of Set 7 | svetlaya
# Processing Record 15 of Set 7 | lensk
# Processing Record 16 of Set 7 | palmer
# Processing Record 17 of Set 7 | kodiak
# Processing Record 18 of Set 7 | susangerd
# Processing Record 19 of Set 7 | los llanos de aridane
# Processing Record 20 of Set 7 | concepcion
# Processing Record 21 of Set 7 | silale
# Processing Record 22 of Set 7 | chumikan
# Processing Record 23 of Set 7 | itupeva
# Processing Record 24 of Set 7 | muros
# Processing Record 25 of Set 7 | north battleford
# Processing Record 26 of Set 7 | andenes
# Processing Record 27 of Set 7 | beruwala
# Processing Record 28 of Set 7 | komsomolskiy
# Processing Record 29 of Set 7 | lanigan
# Processing Record 30 of Set 7 | muroto
# Processing Record 31 of Set 7 | warri
# Processing Record 32 of Set 7 | san luis
# Processing Record 33 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 7 | san francisco
# Processing Record 35 of Set 7 | woodward
# Processing Record 36 of Set 7 | waingapu
# Processing Record 37 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 7 | floro
# Processing Record 39 of Set 7 | paso de carrasco
# Processing Record 40 of Set 7 | saint-pierre
# Processing Record 41 of Set 7 | lufilufi
# Processing Record 42 of Set 7 | oshnaviyeh
# Processing Record 43 of Set 7 | dire dawa
# Processing Record 44 of Set 7 | yerbogachen
# Processing Record 45 of Set 7 | beterou
# Processing Record 46 of Set 7 | la ronge
# Processing Record 47 of Set 7 | frankfort
# Processing Record 48 of Set 7 | flin flon
# Processing Record 49 of Set 7 | lamu
# Processing Record 50 of Set 7 | gavirate
# Processing Record 1 of Set 8 | yulara
# Processing Record 2 of Set 8 | fuyu
# Processing Record 3 of Set 8 | camargo
# Processing Record 4 of Set 8 | marawi
# Processing Record 5 of Set 8 | tofield
# Processing Record 6 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 7 of Set 8 | berlin
# Processing Record 8 of Set 8 | saint anthony
# Processing Record 9 of Set 8 | luan
# Processing Record 10 of Set 8 | ostersund
# Processing Record 11 of Set 8 | east london
# Processing Record 12 of Set 8 | billings
# Processing Record 13 of Set 8 | rodrigues alves
# Processing Record 14 of Set 8 | limulunga
# Processing Record 15 of Set 8 | boyolangu
# Processing Record 16 of Set 8 | mopti
# Processing Record 17 of Set 8 | panaba
# Processing Record 18 of Set 8 | antequera
# Processing Record 19 of Set 8 | haifa
# Processing Record 20 of Set 8 | kapuskasing
# Processing Record 21 of Set 8 | vestmanna
# Processing Record 22 of Set 8 | gulfport
# Processing Record 23 of Set 8 | nalgonda
# Processing Record 24 of Set 8 | baykit
# Processing Record 25 of Set 8 | tuatapere
# Processing Record 26 of Set 8 | egvekinot
# Processing Record 27 of Set 8 | yar-sale
# Processing Record 28 of Set 8 | kruisfontein
# Processing Record 29 of Set 8 | salalah
# Processing Record 30 of Set 8 | ostrovnoy
# Processing Record 31 of Set 8 | skibotn
# Processing Record 32 of Set 8 | rajshahi
# Processing Record 33 of Set 8 | ossora
# Processing Record 34 of Set 8 | santa rosalia
# Processing Record 35 of Set 8 | maiduguri
# Processing Record 36 of Set 8 | lavrentiya
# Processing Record 37 of Set 8 | takoradi
# Processing Record 38 of Set 8 | escarcega
# Processing Record 39 of Set 8 | vokhtoga
# Processing Record 40 of Set 8 | ilheus
# Processing Record 41 of Set 8 | teya
# Processing Record 42 of Set 8 | rockland
# Processing Record 43 of Set 8 | abu dhabi
# Processing Record 44 of Set 8 | ustka
# Processing Record 45 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 8 | rocha
# Processing Record 47 of Set 8 | pacific grove
# Processing Record 48 of Set 8 | amapa
# Processing Record 49 of Set 8 | kununurra
# Processing Record 50 of Set 8 | kedrovyy
# Processing Record 1 of Set 9 | salmas
# Processing Record 2 of Set 9 | koslan
# Processing Record 3 of Set 9 | sawakin
# Processing Record 4 of Set 9 | farmington
# Processing Record 5 of Set 9 | bereda
# Processing Record 6 of Set 9 | arman
# Processing Record 7 of Set 9 | yala
# Processing Record 8 of Set 9 | korla
# Processing Record 9 of Set 9 | tura
# Processing Record 10 of Set 9 | bronnoysund
# Processing Record 11 of Set 9 | wilmington
# Processing Record 12 of Set 9 | tunduru
# City not found. Skipping...
# Processing Record 13 of Set 9 | alta floresta
# Processing Record 14 of Set 9 | jalu
# Processing Record 15 of Set 9 | kautokeino
# Processing Record 16 of Set 9 | miles city
# Processing Record 17 of Set 9 | sahagun
# Processing Record 18 of Set 9 | agnibilekrou
# Processing Record 19 of Set 9 | bom jesus
# Processing Record 20 of Set 9 | maceio
# Processing Record 21 of Set 9 | chikoy
# City not found. Skipping...
# Processing Record 22 of Set 9 | saint george
# Processing Record 23 of Set 9 | kagoro
# Processing Record 24 of Set 9 | mitchell
# Processing Record 25 of Set 9 | singkawang
# Processing Record 26 of Set 9 | dunedin
# Processing Record 27 of Set 9 | gilford
# Processing Record 28 of Set 9 | amga
# Processing Record 29 of Set 9 | nakatsugawa
# Processing Record 30 of Set 9 | pryazha
# Processing Record 31 of Set 9 | aybak
# City not found. Skipping...
# Processing Record 32 of Set 9 | zabaykalsk
# Processing Record 33 of Set 9 | kavaratti
# Processing Record 34 of Set 9 | tupancireta
# Processing Record 35 of Set 9 | vanimo
# Processing Record 36 of Set 9 | omegna
# Processing Record 37 of Set 9 | san jose
# Processing Record 38 of Set 9 | bilma
# Processing Record 39 of Set 9 | saint-augustin
# Processing Record 40 of Set 9 | mamakan
# Processing Record 41 of Set 9 | tondano
# Processing Record 42 of Set 9 | elat
# Processing Record 43 of Set 9 | mabaruma
# Processing Record 44 of Set 9 | moose factory
# Processing Record 45 of Set 9 | taburao
# City not found. Skipping...
# Processing Record 46 of Set 9 | hong gai
# Processing Record 47 of Set 9 | sistranda
# Processing Record 48 of Set 9 | indramayu
# Processing Record 49 of Set 9 | aquiraz
# Processing Record 50 of Set 9 | iranshahr
# Processing Record 1 of Set 10 | itarema
# Processing Record 2 of Set 10 | urumqi
# Processing Record 3 of Set 10 | villa carlos paz
# Processing Record 4 of Set 10 | novopskov
# Processing Record 5 of Set 10 | pudozh
# Processing Record 6 of Set 10 | mitsamiouli
# Processing Record 7 of Set 10 | menomonie
# Processing Record 8 of Set 10 | bose
# Processing Record 9 of Set 10 | bethel
# Processing Record 10 of Set 10 | trairi
# Processing Record 11 of Set 10 | sola
# Processing Record 12 of Set 10 | shemonaikha
# Processing Record 13 of Set 10 | galle
# Processing Record 14 of Set 10 | novosergiyevka
# Processing Record 15 of Set 10 | saint combs
# City not found. Skipping...
# Processing Record 16 of Set 10 | chernyshevskiy
# Processing Record 17 of Set 10 | areka
# Processing Record 18 of Set 10 | conway
# Processing Record 19 of Set 10 | daru
# Processing Record 20 of Set 10 | matagami
# Processing Record 21 of Set 10 | luba
# Processing Record 22 of Set 10 | suntar
# Processing Record 23 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 24 of Set 10 | praia da vitoria
# Processing Record 25 of Set 10 | kita
# Processing Record 26 of Set 10 | atherton
# Processing Record 27 of Set 10 | katobu
# Processing Record 28 of Set 10 | sinnamary
# Processing Record 29 of Set 10 | kloulklubed
# Processing Record 30 of Set 10 | kizema
# Processing Record 31 of Set 10 | diffa
# Processing Record 32 of Set 10 | tenenkou
# Processing Record 33 of Set 10 | sao felix do xingu
# Processing Record 34 of Set 10 | taseyevo
# Processing Record 35 of Set 10 | goias
# Processing Record 36 of Set 10 | kharan
# Processing Record 37 of Set 10 | imeni poliny osipenko
# Processing Record 38 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 39 of Set 10 | les escoumins
# Processing Record 40 of Set 10 | padang
# Processing Record 41 of Set 10 | serenje
# Processing Record 42 of Set 10 | kaili
# Processing Record 43 of Set 10 | canete
# Processing Record 44 of Set 10 | mayo
# Processing Record 45 of Set 10 | karratha
# Processing Record 46 of Set 10 | turukhansk
# Processing Record 47 of Set 10 | poienile de sub munte
# Processing Record 48 of Set 10 | kuryk
# Processing Record 49 of Set 10 | turayf
# Processing Record 50 of Set 10 | koboldo
# City not found. Skipping...
# Processing Record 1 of Set 11 | lashio
# Processing Record 2 of Set 11 | kidal
# Processing Record 3 of Set 11 | keti bandar
# Processing Record 4 of Set 11 | lahaina
# Processing Record 5 of Set 11 | manaure
# Processing Record 6 of Set 11 | tara
# Processing Record 7 of Set 11 | meulaboh
# Processing Record 8 of Set 11 | norfolk
# Processing Record 9 of Set 11 | clarence town
# Processing Record 10 of Set 11 | placerville
# Processing Record 11 of Set 11 | tynda
# Processing Record 12 of Set 11 | chimbote
# Processing Record 13 of Set 11 | sur
# Processing Record 14 of Set 11 | ajacuba
# Processing Record 15 of Set 11 | karatuzskoye
# Processing Record 16 of Set 11 | imbituba
# Processing Record 17 of Set 11 | williston
# Processing Record 18 of Set 11 | caravelas
# Processing Record 19 of Set 11 | alyangula
# Processing Record 20 of Set 11 | yeniseysk
# Processing Record 21 of Set 11 | saint-maximin-la-sainte-baume
# Processing Record 22 of Set 11 | changji
# Processing Record 23 of Set 11 | kaura namoda
# Processing Record 24 of Set 11 | boende
# Processing Record 25 of Set 11 | westport
# Processing Record 26 of Set 11 | ranong
# Processing Record 27 of Set 11 | nanortalik
# Processing Record 28 of Set 11 | kaita
# Processing Record 29 of Set 11 | mandalgovi
# Processing Record 30 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 31 of Set 11 | idrinskoye
# Processing Record 32 of Set 11 | mala
# Processing Record 33 of Set 11 | tonekabon
# Processing Record 34 of Set 11 | san quintin
# Processing Record 35 of Set 11 | ponta delgada
# Processing Record 36 of Set 11 | la uribe
# City not found. Skipping...
# Processing Record 37 of Set 11 | cienaga de flores
# City not found. Skipping...
# Processing Record 38 of Set 11 | tottori
# Processing Record 39 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 40 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 11 | plastun
# Processing Record 42 of Set 11 | abha
# Processing Record 43 of Set 11 | isangel
# Processing Record 44 of Set 11 | birao
# Processing Record 45 of Set 11 | puerto carreno
# Processing Record 46 of Set 11 | paamiut
# Processing Record 47 of Set 11 | sulangan
# Processing Record 48 of Set 11 | xining
# Processing Record 49 of Set 11 | roros
# Processing Record 50 of Set 11 | bacolod
# Processing Record 1 of Set 12 | san buenaventura
# Processing Record 2 of Set 12 | kontagora
# Processing Record 3 of Set 12 | bintulu
# Processing Record 4 of Set 12 | dakar
# Processing Record 5 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 6 of Set 12 | sanandaj
# Processing Record 7 of Set 12 | camopi
# Processing Record 8 of Set 12 | bonthe
# Processing Record 9 of Set 12 | yanam
# Processing Record 10 of Set 12 | vila franca do campo
# Processing Record 11 of Set 12 | malanville
# Processing Record 12 of Set 12 | portland
# Processing Record 13 of Set 12 | alhandra
# Processing Record 14 of Set 12 | manakara
# Processing Record 15 of Set 12 | teahupoo
# Processing Record 16 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 12 | inhambane
# Processing Record 18 of Set 12 | qasigiannguit
# Processing Record 19 of Set 12 | stege
# Processing Record 20 of Set 12 | montepuez
# Processing Record 21 of Set 12 | orchard homes
# Processing Record 22 of Set 12 | matale
# Processing Record 23 of Set 12 | lircay
# Processing Record 24 of Set 12 | muzhi
# Processing Record 25 of Set 12 | vardo
# Processing Record 26 of Set 12 | nioro
# Processing Record 27 of Set 12 | bokoro
# Processing Record 28 of Set 12 | namibe
# Processing Record 29 of Set 12 | aktau
# Processing Record 30 of Set 12 | lapua
# Processing Record 31 of Set 12 | guaira
# Processing Record 32 of Set 12 | harwich
# Processing Record 33 of Set 12 | tautira
# Processing Record 34 of Set 12 | san patricio
# Processing Record 35 of Set 12 | sayyan
# Processing Record 36 of Set 12 | mpika
# Processing Record 37 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 38 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 12 | killybegs
# Processing Record 40 of Set 12 | zhigansk
# Processing Record 41 of Set 12 | balikpapan
# Processing Record 42 of Set 12 | natal
# Processing Record 43 of Set 12 | samana
# Processing Record 44 of Set 12 | joshimath
# Processing Record 45 of Set 12 | pangkalanbuun
# Processing Record 46 of Set 12 | bhadrachalam
# Processing Record 47 of Set 12 | nishihara
# Processing Record 48 of Set 12 | miracema do tocantins
# Processing Record 49 of Set 12 | alice springs
# Processing Record 50 of Set 12 | kuusamo
# Processing Record 1 of Set 13 | hajipur
# Processing Record 2 of Set 13 | upala
# Processing Record 3 of Set 13 | niksic
# Processing Record 4 of Set 13 | plouzane
# Processing Record 5 of Set 13 | chivolo
# Processing Record 6 of Set 13 | berlevag
# Processing Record 7 of Set 13 | triolet
# Processing Record 8 of Set 13 | kieta
# Processing Record 9 of Set 13 | la orilla
# Processing Record 10 of Set 13 | merauke
# Processing Record 11 of Set 13 | zlutice
# Processing Record 12 of Set 13 | vao
# Processing Record 13 of Set 13 | springville
# Processing Record 14 of Set 13 | inta
# Processing Record 15 of Set 13 | mersin
# Processing Record 16 of Set 13 | nanchang
# Processing Record 17 of Set 13 | ardakan
# Processing Record 18 of Set 13 | aykhal
# Processing Record 19 of Set 13 | tahta
# Processing Record 20 of Set 13 | brownsville
# Processing Record 21 of Set 13 | twentynine palms
# Processing Record 22 of Set 13 | ambon
# Processing Record 23 of Set 13 | oussouye
# Processing Record 24 of Set 13 | tommot
# Processing Record 25 of Set 13 | luau
# Processing Record 26 of Set 13 | kologriv
# Processing Record 27 of Set 13 | launceston
# Processing Record 28 of Set 13 | tyukhtet
# Processing Record 29 of Set 13 | poquoson
# Processing Record 30 of Set 13 | corralillo
# Processing Record 31 of Set 13 | port lincoln
# Processing Record 32 of Set 13 | pompeia
# Processing Record 33 of Set 13 | aguas vermelhas
# Processing Record 34 of Set 13 | sorland
# Processing Record 35 of Set 13 | suhut
# Processing Record 36 of Set 13 | safaga
# Processing Record 37 of Set 13 | yeppoon
# Processing Record 38 of Set 13 | half moon bay
# Processing Record 39 of Set 13 | falun
# Processing Record 40 of Set 13 | kaputa
# Processing Record 41 of Set 13 | linqiong
# Processing Record 42 of Set 13 | shumskiy
# Processing Record 43 of Set 13 | martapura
# Processing Record 44 of Set 13 | sao joao da barra
# Processing Record 45 of Set 13 | kamalia
# Processing Record 46 of Set 13 | catuday
# Processing Record 47 of Set 13 | orangeburg
# Processing Record 48 of Set 13 | jiaocheng
# Processing Record 49 of Set 13 | yicheng
# Processing Record 50 of Set 13 | dno
# Processing Record 1 of Set 14 | troitskoye
# Processing Record 2 of Set 14 | wamba
# Processing Record 3 of Set 14 | cap-aux-meules
# Processing Record 4 of Set 14 | lazaro cardenas
# Processing Record 5 of Set 14 | kyrylivka
# Processing Record 6 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 14 | santana do livramento
# Processing Record 8 of Set 14 | nsanje
# Processing Record 9 of Set 14 | nichinan
# Processing Record 10 of Set 14 | kainantu
# Processing Record 11 of Set 14 | bowen
# Processing Record 12 of Set 14 | suez
# Processing Record 13 of Set 14 | one hundred mile house
# City not found. Skipping...
# Processing Record 14 of Set 14 | bambanglipuro
# Processing Record 15 of Set 14 | visby
# Processing Record 16 of Set 14 | ushtobe
# Processing Record 17 of Set 14 | san rafael
# Processing Record 18 of Set 14 | gazimurskiy zavod
# Processing Record 19 of Set 14 | novo aripuana
# Processing Record 20 of Set 14 | kalevala
# Processing Record 21 of Set 14 | pochutla
# Processing Record 22 of Set 14 | drayton valley
# Processing Record 23 of Set 14 | miquelon
# Processing Record 24 of Set 14 | dujuma
# City not found. Skipping...
# Processing Record 25 of Set 14 | thunder bay
# Processing Record 26 of Set 14 | jardim
# Processing Record 27 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 28 of Set 14 | ascension
# Processing Record 29 of Set 14 | banepa
# Processing Record 30 of Set 14 | olinda
# Processing Record 31 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 32 of Set 14 | ternate
# Processing Record 33 of Set 14 | mombasa
# Processing Record 34 of Set 14 | zenzeli
# Processing Record 35 of Set 14 | nyon
# Processing Record 36 of Set 14 | hay river
# Processing Record 37 of Set 14 | mahibadhoo
# Processing Record 38 of Set 14 | kargasok
# Processing Record 39 of Set 14 | mountain home
# Processing Record 40 of Set 14 | muncar
# Processing Record 41 of Set 14 | nanning
# Processing Record 42 of Set 14 | ilebo
# Processing Record 43 of Set 14 | changli
# Processing Record 44 of Set 14 | balkhash
# Processing Record 45 of Set 14 | libertador general san martin
# Processing Record 46 of Set 14 | chapais
# Processing Record 47 of Set 14 | zheleznodorozhnyy
# Processing Record 48 of Set 14 | lac du bonnet
# Processing Record 49 of Set 14 | nadvoitsy
# Processing Record 50 of Set 14 | mecca
# Processing Record 1 of Set 15 | taltal
# Processing Record 2 of Set 15 | mosquera
# Processing Record 3 of Set 15 | morehead
# Processing Record 4 of Set 15 | concepcion del oro
# Processing Record 5 of Set 15 | baie-comeau
# Processing Record 6 of Set 15 | roura
# Processing Record 7 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 8 of Set 15 | havoysund
# Processing Record 9 of Set 15 | katherine
# Processing Record 10 of Set 15 | plettenberg bay
# Processing Record 11 of Set 15 | kozova
# Processing Record 12 of Set 15 | ayan
# Processing Record 13 of Set 15 | mutare
# Processing Record 14 of Set 15 | cristalina
# Processing Record 15 of Set 15 | boa vista
# Processing Record 16 of Set 15 | puri
# Processing Record 17 of Set 15 | nouadhibou
# Processing Record 18 of Set 15 | labuhan
# Processing Record 19 of Set 15 | bakel
# Processing Record 20 of Set 15 | taytay
# Processing Record 21 of Set 15 | waddan
# Processing Record 22 of Set 15 | cauquenes
# Processing Record 23 of Set 15 | ajdabiya
# Processing Record 24 of Set 15 | thano bula khan
# City not found. Skipping...
# Processing Record 25 of Set 15 | great bend
# Processing Record 26 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 15 | guantanamo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 672

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas -53.1500  -70.9167     53.71        62          40
# 1    San Vicente -26.6167  -54.1333     68.49        56           0
# 2      Upernavik  72.7868  -56.1549     -9.20        86         100
# 3    New Norfolk -42.7826  147.0587     74.91        44          11
# 4         Tutoia  -2.7619  -42.2744     77.09        85          97
# 5         Atuona  -9.8000 -139.0333     79.12        79          21
# 6  Mar Del Plata -38.0023  -57.5575     69.87        86           4
# 7        Ballina -28.8667  153.5667     82.02        84           7
# 8        Rikitea -23.1203 -134.9692     78.46        76          90
# 9         Albany  42.6001  -73.9662     31.23        78          88
#
#    Wind Speed Country Current Description
# 0       26.46      CL    scattered clouds
# 1        2.59      AR           clear sky
# 2        4.79      GL     overcast clouds
# 3        5.01      AU          few clouds
# 4        8.88      BR     overcast clouds
# 5       20.71      PF          few clouds
# 6        5.01      AR           clear sky
# 7       13.31      AU           clear sky
# 8       13.69      PF          light rain
# 9        5.37      US     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas      CL -53.1500  -70.9167     53.71        62          40
# 1    San Vicente      AR -26.6167  -54.1333     68.49        56           0
# 2      Upernavik      GL  72.7868  -56.1549     -9.20        86         100
# 3    New Norfolk      AU -42.7826  147.0587     74.91        44          11
# 4         Tutoia      BR  -2.7619  -42.2744     77.09        85          97
# 5         Atuona      PF  -9.8000 -139.0333     79.12        79          21
# 6  Mar Del Plata      AR -38.0023  -57.5575     69.87        86           4
# 7        Ballina      AU -28.8667  153.5667     82.02        84           7
# 8        Rikitea      PF -23.1203 -134.9692     78.46        76          90
# 9         Albany      US  42.6001  -73.9662     31.23        78          88
#
#    Wind Speed Current Description
# 0       26.46    scattered clouds
# 1        2.59           clear sky
# 2        4.79     overcast clouds
# 3        5.01          few clouds
# 4        8.88     overcast clouds
# 5       20.71          few clouds
# 6        5.01           clear sky
# 7       13.31           clear sky
# 8       13.69          light rain
# 9        5.37     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
